# %%
# import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time
from datetime import datetime

# %%
# create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
# Build the API URL 
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_description})

# If an error is experienced, skip the city.
    except(KeyError):
        print(f'{city} has not been found. Skipping...')
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | tuktoyaktuk
# Processing Record 3 of Set 1 | saskylakh
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | carnarvon
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | barentsburg
# barentsburg has not been found. Skipping...
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | ponta do sol
# Processing Record 10 of Set 1 | itaituba
# Processing Record 11 of Set 1 | cayenne
# Processing Record 12 of Set 1 | mago
# Processing Record 13 of Set 1 | severomuysk
# Processing Record 14 of Set 1 | port alfred
# Processing Record 15 of Set 1 | waitara
# Processing Record 16 of Set 1 | hasaki
# Processing Record 17 of Set 1 | butaritari
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | louisbourg
# louisbourg has not been found. Skipping...
# Processing Record 20 of Set 1 | provideniya
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | spornoye
# Processing Record 23 of Set 1 | longyearbyen
# Processing Record 24 of Set 1 | sur
# Processing Record 25 of Set 1 | jumla
# Processing Record 26 of Set 1 | alyangula
# Processing Record 27 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 1 | jatai
# Processing Record 29 of Set 1 | andevoranto
# andevoranto has not been found. Skipping...
# Processing Record 30 of Set 1 | arraial do cabo
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | ancud
# Processing Record 34 of Set 1 | kapaa
# Processing Record 35 of Set 1 | komsomolskiy
# Processing Record 36 of Set 1 | qaanaaq
# Processing Record 37 of Set 1 | illoqqortoormiut
# illoqqortoormiut has not been found. Skipping...
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | gorom-gorom
# Processing Record 40 of Set 1 | westport
# Processing Record 41 of Set 1 | asau
# Processing Record 42 of Set 1 | yabrud
# Processing Record 43 of Set 1 | kodiak
# Processing Record 44 of Set 1 | saryshagan
# saryshagan has not been found. Skipping...
# Processing Record 45 of Set 1 | tasiilaq
# Processing Record 46 of Set 1 | san juan
# Processing Record 47 of Set 1 | gazanjyk
# Processing Record 48 of Set 1 | siverek
# Processing Record 49 of Set 1 | airai
# Processing Record 50 of Set 1 | yar-sale
# Processing Record 1 of Set 2 | tsihombe
# tsihombe has not been found. Skipping...
# Processing Record 2 of Set 2 | lebu
# Processing Record 3 of Set 2 | kutum
# Processing Record 4 of Set 2 | husavik
# Processing Record 5 of Set 2 | vaini
# Processing Record 6 of Set 2 | maceio
# Processing Record 7 of Set 2 | hithadhoo
# Processing Record 8 of Set 2 | sobolevo
# Processing Record 9 of Set 2 | cidreira
# Processing Record 10 of Set 2 | gat
# Processing Record 11 of Set 2 | ketchikan
# Processing Record 12 of Set 2 | mabaruma
# Processing Record 13 of Set 2 | waipawa
# Processing Record 14 of Set 2 | eureka
# Processing Record 15 of Set 2 | chunian
# Processing Record 16 of Set 2 | auki
# Processing Record 17 of Set 2 | along
# Processing Record 18 of Set 2 | yarmouth
# Processing Record 19 of Set 2 | ibra
# Processing Record 20 of Set 2 | bredasdorp
# Processing Record 21 of Set 2 | biak
# Processing Record 22 of Set 2 | fortuna
# Processing Record 23 of Set 2 | dalbandin
# Processing Record 24 of Set 2 | east london
# Processing Record 25 of Set 2 | corn island
# Processing Record 26 of Set 2 | esperance
# Processing Record 27 of Set 2 | cherskiy
# Processing Record 28 of Set 2 | phu khieo
# phu khieo has not been found. Skipping...
# Processing Record 29 of Set 2 | payo
# Processing Record 30 of Set 2 | yining
# Processing Record 31 of Set 2 | avarua
# Processing Record 32 of Set 2 | prieska
# Processing Record 33 of Set 2 | salcininkai
# Processing Record 34 of Set 2 | saldanha
# Processing Record 35 of Set 2 | pelotas
# Processing Record 36 of Set 2 | new norfolk
# Processing Record 37 of Set 2 | ribeira grande
# Processing Record 38 of Set 2 | buchanan
# Processing Record 39 of Set 2 | nizhneyansk
# nizhneyansk has not been found. Skipping...
# Processing Record 40 of Set 2 | rosario oeste
# Processing Record 41 of Set 2 | yumen
# Processing Record 42 of Set 2 | taolanaro
# taolanaro has not been found. Skipping...
# Processing Record 43 of Set 2 | mahebourg
# Processing Record 44 of Set 2 | lolua
# lolua has not been found. Skipping...
# Processing Record 45 of Set 2 | bengkulu
# Processing Record 46 of Set 2 | hilo
# Processing Record 47 of Set 2 | sitka
# Processing Record 48 of Set 2 | tokur
# Processing Record 49 of Set 2 | tuatapere
# Processing Record 50 of Set 2 | tessalit
# Processing Record 1 of Set 3 | attawapiskat
# attawapiskat has not been found. Skipping...
# Processing Record 2 of Set 3 | rawatsar
# Processing Record 3 of Set 3 | salinopolis
# Processing Record 4 of Set 3 | dikson
# Processing Record 5 of Set 3 | kaitangata
# Processing Record 6 of Set 3 | azogues
# Processing Record 7 of Set 3 | ucluelet
# Processing Record 8 of Set 3 | itanhem
# Processing Record 9 of Set 3 | sao filipe
# Processing Record 10 of Set 3 | klaksvik
# Processing Record 11 of Set 3 | grindavik
# Processing Record 12 of Set 3 | naftah
# naftah has not been found. Skipping...
# Processing Record 13 of Set 3 | praia
# Processing Record 14 of Set 3 | portland
# Processing Record 15 of Set 3 | georgetown
# Processing Record 16 of Set 3 | salo
# Processing Record 17 of Set 3 | galesong
# Processing Record 18 of Set 3 | yulara
# Processing Record 19 of Set 3 | barrow
# Processing Record 20 of Set 3 | sogne
# Processing Record 21 of Set 3 | upernavik
# Processing Record 22 of Set 3 | cabo san lucas
# Processing Record 23 of Set 3 | albany
# Processing Record 24 of Set 3 | sao gabriel da cachoeira
# Processing Record 25 of Set 3 | lima
# Processing Record 26 of Set 3 | port elizabeth
# Processing Record 27 of Set 3 | kamenskoye
# kamenskoye has not been found. Skipping...
# Processing Record 28 of Set 3 | rusape
# Processing Record 29 of Set 3 | suez
# Processing Record 30 of Set 3 | rawannawi
# rawannawi has not been found. Skipping...
# Processing Record 31 of Set 3 | tazovskiy
# Processing Record 32 of Set 3 | sola
# Processing Record 33 of Set 3 | nyurba
# Processing Record 34 of Set 3 | hobart
# Processing Record 35 of Set 3 | souillac
# Processing Record 36 of Set 3 | chagda
# chagda has not been found. Skipping...
# Processing Record 37 of Set 3 | vila velha
# Processing Record 38 of Set 3 | sol-iletsk
# Processing Record 39 of Set 3 | marienburg
# Processing Record 40 of Set 3 | otradnoye
# Processing Record 41 of Set 3 | grand river south east
# grand river south east has not been found. Skipping...
# Processing Record 42 of Set 3 | dicabisagan
# Processing Record 43 of Set 3 | bambous virieux
# Processing Record 44 of Set 3 | puerto ayora
# Processing Record 45 of Set 3 | praia da vitoria
# Processing Record 46 of Set 3 | calvinia
# Processing Record 47 of Set 3 | geraldton
# Processing Record 48 of Set 3 | satao
# Processing Record 49 of Set 3 | beringovskiy
# Processing Record 50 of Set 3 | nuuk
# Processing Record 1 of Set 4 | atuona
# Processing Record 2 of Set 4 | faanui
# Processing Record 3 of Set 4 | rorvik
# Processing Record 4 of Set 4 | zhitikara
# zhitikara has not been found. Skipping...
# Processing Record 5 of Set 4 | guerrero negro
# Processing Record 6 of Set 4 | teahupoo
# Processing Record 7 of Set 4 | shubarkuduk
# Processing Record 8 of Set 4 | vila franca do campo
# Processing Record 9 of Set 4 | norman wells
# Processing Record 10 of Set 4 | jamestown
# Processing Record 11 of Set 4 | jieshou
# Processing Record 12 of Set 4 | iqaluit
# Processing Record 13 of Set 4 | torbay
# Processing Record 14 of Set 4 | adrar
# Processing Record 15 of Set 4 | vaitupu
# vaitupu has not been found. Skipping...
# Processing Record 16 of Set 4 | traverse city
# Processing Record 17 of Set 4 | yenangyaung
# Processing Record 18 of Set 4 | sentyabrskiy
# sentyabrskiy has not been found. Skipping...
# Processing Record 19 of Set 4 | aljezur
# Processing Record 20 of Set 4 | yeppoon
# Processing Record 21 of Set 4 | lashio
# Processing Record 22 of Set 4 | surdulica
# Processing Record 23 of Set 4 | phalaborwa
# Processing Record 24 of Set 4 | belushya guba
# belushya guba has not been found. Skipping...
# Processing Record 25 of Set 4 | coos bay
# Processing Record 26 of Set 4 | kapoeta
# Processing Record 27 of Set 4 | severo-kurilsk
# Processing Record 28 of Set 4 | amderma
# amderma has not been found. Skipping...
# Processing Record 29 of Set 4 | constitucion
# Processing Record 30 of Set 4 | rungata
# rungata has not been found. Skipping...
# Processing Record 31 of Set 4 | nouadhibou
# Processing Record 32 of Set 4 | tarma
# Processing Record 33 of Set 4 | los llanos de aridane
# Processing Record 34 of Set 4 | bitung
# Processing Record 35 of Set 4 | kundiawa
# Processing Record 36 of Set 4 | neryungri
# Processing Record 37 of Set 4 | kermanshah
# Processing Record 38 of Set 4 | taltal
# Processing Record 39 of Set 4 | finnsnes
# Processing Record 40 of Set 4 | micheweni
# Processing Record 41 of Set 4 | comodoro rivadavia
# Processing Record 42 of Set 4 | umzimvubu
# umzimvubu has not been found. Skipping...
# Processing Record 43 of Set 4 | kenai
# Processing Record 44 of Set 4 | talnakh
# Processing Record 45 of Set 4 | prescott
# Processing Record 46 of Set 4 | bowen
# Processing Record 47 of Set 4 | spasskoye
# Processing Record 48 of Set 4 | fairbanks
# Processing Record 49 of Set 4 | jardim
# Processing Record 50 of Set 4 | rocha
# Processing Record 1 of Set 5 | tanabe
# Processing Record 2 of Set 5 | bahia blanca
# Processing Record 3 of Set 5 | ilulissat
# Processing Record 4 of Set 5 | fukue
# Processing Record 5 of Set 5 | miracema do tocantins
# Processing Record 6 of Set 5 | shimoda
# Processing Record 7 of Set 5 | gejiu
# Processing Record 8 of Set 5 | kodinsk
# Processing Record 9 of Set 5 | mys shmidta
# mys shmidta has not been found. Skipping...
# Processing Record 10 of Set 5 | castro
# Processing Record 11 of Set 5 | slave lake
# Processing Record 12 of Set 5 | malakwal
# Processing Record 13 of Set 5 | nikolskoye
# Processing Record 14 of Set 5 | ahipara
# Processing Record 15 of Set 5 | vila do maio
# Processing Record 16 of Set 5 | vestmannaeyjar
# Processing Record 17 of Set 5 | paamiut
# Processing Record 18 of Set 5 | itarema
# Processing Record 19 of Set 5 | la ronge
# Processing Record 20 of Set 5 | caraquet
# Processing Record 21 of Set 5 | xuddur
# Processing Record 22 of Set 5 | kitgum
# Processing Record 23 of Set 5 | nadym
# Processing Record 24 of Set 5 | boa vista
# Processing Record 25 of Set 5 | honiara
# Processing Record 26 of Set 5 | chernyshevskiy
# Processing Record 27 of Set 5 | charlottetown
# Processing Record 28 of Set 5 | chinsali
# Processing Record 29 of Set 5 | maridi
# Processing Record 30 of Set 5 | kirovsk
# Processing Record 31 of Set 5 | lagdo
# Processing Record 32 of Set 5 | mount gambier
# Processing Record 33 of Set 5 | bardiyah
# Processing Record 34 of Set 5 | takoradi
# Processing Record 35 of Set 5 | krasnyy chikoy
# Processing Record 36 of Set 5 | khatanga
# Processing Record 37 of Set 5 | roald
# Processing Record 38 of Set 5 | mar del plata
# Processing Record 39 of Set 5 | bababe
# bababe has not been found. Skipping...
# Processing Record 40 of Set 5 | natal
# Processing Record 41 of Set 5 | chokurdakh
# Processing Record 42 of Set 5 | khash
# Processing Record 43 of Set 5 | saint-pierre
# Processing Record 44 of Set 5 | thompson
# Processing Record 45 of Set 5 | nguru
# Processing Record 46 of Set 5 | jiddah
# jiddah has not been found. Skipping...
# Processing Record 47 of Set 5 | uige
# Processing Record 48 of Set 5 | samusu
# samusu has not been found. Skipping...
# Processing Record 49 of Set 5 | san cristobal
# Processing Record 50 of Set 5 | gharb
# gharb has not been found. Skipping...
# Processing Record 1 of Set 6 | colorado springs
# Processing Record 2 of Set 6 | santiago
# Processing Record 3 of Set 6 | nishihara
# Processing Record 4 of Set 6 | abu dhabi
# Processing Record 5 of Set 6 | nabari
# Processing Record 6 of Set 6 | kruisfontein
# Processing Record 7 of Set 6 | stornoway
# Processing Record 8 of Set 6 | saint george
# Processing Record 9 of Set 6 | sharan
# Processing Record 10 of Set 6 | araouane
# Processing Record 11 of Set 6 | pisco
# Processing Record 12 of Set 6 | port lincoln
# Processing Record 13 of Set 6 | saurimo
# Processing Record 14 of Set 6 | acapulco
# Processing Record 15 of Set 6 | clyde river
# Processing Record 16 of Set 6 | nicoya
# Processing Record 17 of Set 6 | santa lucia
# Processing Record 18 of Set 6 | palabuhanratu
# palabuhanratu has not been found. Skipping...
# Processing Record 19 of Set 6 | provost
# Processing Record 20 of Set 6 | bertoua
# Processing Record 21 of Set 6 | bundaberg
# Processing Record 22 of Set 6 | malanje
# Processing Record 23 of Set 6 | lingao
# Processing Record 24 of Set 6 | urucui
# Processing Record 25 of Set 6 | wundanyi
# Processing Record 26 of Set 6 | kayerkan
# Processing Record 27 of Set 6 | tiksi
# Processing Record 28 of Set 6 | dunedin
# Processing Record 29 of Set 6 | mortka
# Processing Record 30 of Set 6 | kashan
# Processing Record 31 of Set 6 | scunthorpe
# Processing Record 32 of Set 6 | samarai
# Processing Record 33 of Set 6 | batagay-alyta
# Processing Record 34 of Set 6 | emerald
# Processing Record 35 of Set 6 | kumluca
# Processing Record 36 of Set 6 | hennenman
# Processing Record 37 of Set 6 | isangel
# Processing Record 38 of Set 6 | berlevag
# Processing Record 39 of Set 6 | kamphaeng phet
# Processing Record 40 of Set 6 | luanda
# Processing Record 41 of Set 6 | nanchang
# Processing Record 42 of Set 6 | eyl
# Processing Record 43 of Set 6 | ugoofaaru
# Processing Record 44 of Set 6 | flinders
# Processing Record 45 of Set 6 | weiden
# Processing Record 46 of Set 6 | hauterive
# Processing Record 47 of Set 6 | chuy
# Processing Record 48 of Set 6 | saint-philippe
# Processing Record 49 of Set 6 | hay river
# Processing Record 50 of Set 6 | dingle
# Processing Record 1 of Set 7 | mehamn
# Processing Record 2 of Set 7 | okha
# Processing Record 3 of Set 7 | tiznit
# Processing Record 4 of Set 7 | leshukonskoye
# Processing Record 5 of Set 7 | misratah
# Processing Record 6 of Set 7 | guangyuan
# Processing Record 7 of Set 7 | livingston
# Processing Record 8 of Set 7 | dekar
# Processing Record 9 of Set 7 | port hardy
# Processing Record 10 of Set 7 | tigil
# Processing Record 11 of Set 7 | kupang
# Processing Record 12 of Set 7 | avera
# Processing Record 13 of Set 7 | diamantino
# Processing Record 14 of Set 7 | padang
# Processing Record 15 of Set 7 | junagarh
# Processing Record 16 of Set 7 | burica
# burica has not been found. Skipping...
# Processing Record 17 of Set 7 | ganzhou
# Processing Record 18 of Set 7 | marcona
# marcona has not been found. Skipping...
# Processing Record 19 of Set 7 | lompoc
# Processing Record 20 of Set 7 | ust-nera
# Processing Record 21 of Set 7 | bethel
# Processing Record 22 of Set 7 | hamilton
# Processing Record 23 of Set 7 | farmington
# Processing Record 24 of Set 7 | sept-iles
# Processing Record 25 of Set 7 | la roche-sur-yon
# Processing Record 26 of Set 7 | bathsheba
# Processing Record 27 of Set 7 | brae
# Processing Record 28 of Set 7 | port-gentil
# Processing Record 29 of Set 7 | morant bay
# Processing Record 30 of Set 7 | mino
# Processing Record 31 of Set 7 | colares
# Processing Record 32 of Set 7 | maumere
# Processing Record 33 of Set 7 | lalmohan
# Processing Record 34 of Set 7 | suzhou
# Processing Record 35 of Set 7 | nauta
# Processing Record 36 of Set 7 | victoria
# Processing Record 37 of Set 7 | sri aman
# Processing Record 38 of Set 7 | umm lajj
# Processing Record 39 of Set 7 | dzhusaly
# dzhusaly has not been found. Skipping...
# Processing Record 40 of Set 7 | san ramon
# Processing Record 41 of Set 7 | belaya gora
# Processing Record 42 of Set 7 | trat
# Processing Record 43 of Set 7 | aksu
# Processing Record 44 of Set 7 | narsaq
# Processing Record 45 of Set 7 | salalah
# Processing Record 46 of Set 7 | jalu
# Processing Record 47 of Set 7 | formosa
# Processing Record 48 of Set 7 | santa cruz cabralia
# Processing Record 49 of Set 7 | luderitz
# Processing Record 50 of Set 7 | ilovka
# Processing Record 1 of Set 8 | pevek
# Processing Record 2 of Set 8 | aklavik
# Processing Record 3 of Set 8 | te anau
# Processing Record 4 of Set 8 | luang prabang
# Processing Record 5 of Set 8 | bolungarvik
# bolungarvik has not been found. Skipping...
# Processing Record 6 of Set 8 | mezen
# Processing Record 7 of Set 8 | karaul
# karaul has not been found. Skipping...
# Processing Record 8 of Set 8 | san patricio
# Processing Record 9 of Set 8 | leningradskiy
# Processing Record 10 of Set 8 | saleaula
# saleaula has not been found. Skipping...
# Processing Record 11 of Set 8 | tual
# Processing Record 12 of Set 8 | huarmey
# Processing Record 13 of Set 8 | ballina
# Processing Record 14 of Set 8 | salaga
# Processing Record 15 of Set 8 | bubaque
# Processing Record 16 of Set 8 | mantua
# Processing Record 17 of Set 8 | vaitape
# Processing Record 18 of Set 8 | verkhoyansk
# Processing Record 19 of Set 8 | ardatov
# Processing Record 20 of Set 8 | puerto escondido
# Processing Record 21 of Set 8 | la asuncion
# Processing Record 22 of Set 8 | broken hill
# Processing Record 23 of Set 8 | sigulda
# Processing Record 24 of Set 8 | nanortalik
# Processing Record 25 of Set 8 | owando
# Processing Record 26 of Set 8 | coihaique
# Processing Record 27 of Set 8 | da nang
# Processing Record 28 of Set 8 | coruripe
# Processing Record 29 of Set 8 | bull savanna
# Processing Record 30 of Set 8 | kutahya
# Processing Record 31 of Set 8 | warwick
# Processing Record 32 of Set 8 | york
# Processing Record 33 of Set 8 | kalaleh
# Processing Record 34 of Set 8 | nhulunbuy
# Processing Record 35 of Set 8 | at-bashi
# Processing Record 36 of Set 8 | broome
# Processing Record 37 of Set 8 | saint anthony
# Processing Record 38 of Set 8 | tabuny
# Processing Record 39 of Set 8 | bayangol
# Processing Record 40 of Set 8 | utiroa
# utiroa has not been found. Skipping...
# Processing Record 41 of Set 8 | kirakira
# Processing Record 42 of Set 8 | srednekolymsk
# Processing Record 43 of Set 8 | asosa
# Processing Record 44 of Set 8 | julio de castilhos
# Processing Record 45 of Set 8 | kavieng
# Processing Record 46 of Set 8 | harper
# Processing Record 47 of Set 8 | veshenskaya
# Processing Record 48 of Set 8 | tadine
# Processing Record 49 of Set 8 | baculin
# Processing Record 50 of Set 8 | oistins
# Processing Record 1 of Set 9 | balkanabat
# Processing Record 2 of Set 9 | perth
# Processing Record 3 of Set 9 | roros
# Processing Record 4 of Set 9 | tatishchevo
# Processing Record 5 of Set 9 | bargal
# bargal has not been found. Skipping...
# Processing Record 6 of Set 9 | plouzane
# Processing Record 7 of Set 9 | ossora
# Processing Record 8 of Set 9 | ixtapa
# Processing Record 9 of Set 9 | kropotkin
# Processing Record 10 of Set 9 | camana
# Processing Record 11 of Set 9 | margate
# Processing Record 12 of Set 9 | half moon bay
# Processing Record 13 of Set 9 | launceston
# Processing Record 14 of Set 9 | amahai
# Processing Record 15 of Set 9 | ahuimanu
# Processing Record 16 of Set 9 | angoram
# Processing Record 17 of Set 9 | gairo
# Processing Record 18 of Set 9 | valdivia
# Processing Record 19 of Set 9 | goderich
# Processing Record 20 of Set 9 | port shepstone
# Processing Record 21 of Set 9 | sibu
# Processing Record 22 of Set 9 | kirksville
# Processing Record 23 of Set 9 | namatanai
# Processing Record 24 of Set 9 | ojinaga
# Processing Record 25 of Set 9 | shingu
# Processing Record 26 of Set 9 | sfantu gheorghe
# Processing Record 27 of Set 9 | dhuburi
# Processing Record 28 of Set 9 | bandarbeyla
# Processing Record 29 of Set 9 | djougou
# Processing Record 30 of Set 9 | tyup
# Processing Record 31 of Set 9 | kushiro
# Processing Record 32 of Set 9 | xinzhou
# Processing Record 33 of Set 9 | murray bridge
# Processing Record 34 of Set 9 | coquimbo
# Processing Record 35 of Set 9 | nampa
# Processing Record 36 of Set 9 | buraydah
# Processing Record 37 of Set 9 | horadiz
# Processing Record 38 of Set 9 | taitung
# Processing Record 39 of Set 9 | makakilo city
# Processing Record 40 of Set 9 | ntchisi
# Processing Record 41 of Set 9 | dudinka
# Processing Record 42 of Set 9 | kant
# Processing Record 43 of Set 9 | saint-augustin
# Processing Record 44 of Set 9 | simbahan
# Processing Record 45 of Set 9 | bogo
# Processing Record 46 of Set 9 | shrewsbury
# Processing Record 47 of Set 9 | pimentel
# Processing Record 48 of Set 9 | karratha
# Processing Record 49 of Set 9 | jackson
# Processing Record 50 of Set 9 | okhotsk
# Processing Record 1 of Set 10 | katherine
# Processing Record 2 of Set 10 | maebaru
# Processing Record 3 of Set 10 | tecoanapa
# Processing Record 4 of Set 10 | maxixe
# Processing Record 5 of Set 10 | rio cuarto
# Processing Record 6 of Set 10 | lugovoy
# Processing Record 7 of Set 10 | poum
# Processing Record 8 of Set 10 | meulaboh
# Processing Record 9 of Set 10 | kysyl-syr
# Processing Record 10 of Set 10 | dzaoudzi
# Processing Record 11 of Set 10 | lavrentiya
# Processing Record 12 of Set 10 | chapais
# Processing Record 13 of Set 10 | godalming
# Processing Record 14 of Set 10 | muros
# Processing Record 15 of Set 10 | acajutla
# Processing Record 16 of Set 10 | maragogi
# Processing Record 17 of Set 10 | gawler
# Processing Record 18 of Set 10 | katsuura
# Processing Record 19 of Set 10 | mahendragarh
# Processing Record 20 of Set 10 | mont-dore
# Processing Record 21 of Set 10 | ardistan
# ardistan has not been found. Skipping...
# Processing Record 22 of Set 10 | vardo
# Processing Record 23 of Set 10 | faya
# Processing Record 24 of Set 10 | mount isa
# Processing Record 25 of Set 10 | jiroft
# jiroft has not been found. Skipping...
# Processing Record 26 of Set 10 | cap malheureux
# Processing Record 27 of Set 10 | halalo
# halalo has not been found. Skipping...
# Processing Record 28 of Set 10 | puerto armuelles
# Processing Record 29 of Set 10 | sosnovo-ozerskoye
# Processing Record 30 of Set 10 | flin flon
# Processing Record 31 of Set 10 | kalakamati
# Processing Record 32 of Set 10 | one hundred mile house
# one hundred mile house has not been found. Skipping...
# Processing Record 33 of Set 10 | soe
# Processing Record 34 of Set 10 | port hedland
# Processing Record 35 of Set 10 | ihosy
# Processing Record 36 of Set 10 | machhiwara
# Processing Record 37 of Set 10 | dori
# Processing Record 38 of Set 10 | syamzha
# Processing Record 39 of Set 10 | san jose
# Processing Record 40 of Set 10 | akhmim
# Processing Record 41 of Set 10 | mora
# Processing Record 42 of Set 10 | puerto lempira
# Processing Record 43 of Set 10 | ostersund
# Processing Record 44 of Set 10 | nueva helvecia
# Processing Record 45 of Set 10 | sa kaeo
# Processing Record 46 of Set 10 | saint-joseph
# Processing Record 47 of Set 10 | oktyabrskiy
# Processing Record 48 of Set 10 | evensk
# Processing Record 49 of Set 10 | mbanza-ngungu
# Processing Record 50 of Set 10 | khandbari
# Processing Record 1 of Set 11 | sorvag
# sorvag has not been found. Skipping...
# Processing Record 2 of Set 11 | belmonte
# Processing Record 3 of Set 11 | lovozero
# Processing Record 4 of Set 11 | ulladulla
# Processing Record 5 of Set 11 | akyab
# Processing Record 6 of Set 11 | pathein
# Processing Record 7 of Set 11 | beloha
# Processing Record 8 of Set 11 | horsham
# Processing Record 9 of Set 11 | richards bay
# Processing Record 10 of Set 11 | bonthe
# Processing Record 11 of Set 11 | watertown
# Processing Record 12 of Set 11 | linxia
# Processing Record 13 of Set 11 | zambezi
# Processing Record 14 of Set 11 | erenhot
# Processing Record 15 of Set 11 | cururupu
# Processing Record 16 of Set 11 | neokhorion
# Processing Record 17 of Set 11 | labuhan
# Processing Record 18 of Set 11 | lethem
# Processing Record 19 of Set 11 | russell
# Processing Record 20 of Set 11 | namibe
# Processing Record 21 of Set 11 | honningsvag
# Processing Record 22 of Set 11 | bo phloi
# Processing Record 23 of Set 11 | roma
# Processing Record 24 of Set 11 | piacabucu
# Processing Record 25 of Set 11 | tambo
# Processing Record 26 of Set 11 | aflu
# aflu has not been found. Skipping...
# Processing Record 27 of Set 11 | kramat
# Processing Record 28 of Set 11 | harsin
# Processing Record 29 of Set 11 | talcahuano
# Processing Record 30 of Set 11 | patiala
# Processing Record 31 of Set 11 | kamenka
# Processing Record 32 of Set 11 | requena
# Processing Record 33 of Set 11 | marsa matruh
# Processing Record 34 of Set 11 | olafsvik
# Processing Record 35 of Set 11 | nosy varika
# Processing Record 36 of Set 11 | kampong chhnang
# Processing Record 37 of Set 11 | akdepe
# Processing Record 38 of Set 11 | hervey bay
# Processing Record 39 of Set 11 | bennington
# Processing Record 40 of Set 11 | xudat
# Processing Record 41 of Set 11 | terrak
# Processing Record 42 of Set 11 | kaduqli
# Processing Record 43 of Set 11 | sandnessjoen
# Processing Record 44 of Set 11 | oussouye
# Processing Record 45 of Set 11 | indianola
# Processing Record 46 of Set 11 | chernukha
# Processing Record 47 of Set 11 | maniitsoq
# Processing Record 48 of Set 11 | oranjemund
# Processing Record 49 of Set 11 | ca mau
# Processing Record 50 of Set 11 | teguise
# Processing Record 1 of Set 12 | uyuni
# Processing Record 2 of Set 12 | sydney
# Processing Record 3 of Set 12 | igurusi
# Processing Record 4 of Set 12 | vao
# Processing Record 5 of Set 12 | taureni
# Processing Record 6 of Set 12 | sorong
# Processing Record 7 of Set 12 | anadyr
# Processing Record 8 of Set 12 | caravelas
# Processing Record 9 of Set 12 | kristiansund
# Processing Record 10 of Set 12 | sinnamary
# Processing Record 11 of Set 12 | claresholm
# Processing Record 12 of Set 12 | nampula
# Processing Record 13 of Set 12 | meyungs
# meyungs has not been found. Skipping...
# Processing Record 14 of Set 12 | crossville
# Processing Record 15 of Set 12 | ambodifototra
# ambodifototra has not been found. Skipping...
# Processing Record 16 of Set 12 | buta
# Processing Record 17 of Set 12 | camargo
# Processing Record 18 of Set 12 | barwadih
# Processing Record 19 of Set 12 | dandong
# Processing Record 20 of Set 12 | porbandar
# Processing Record 21 of Set 12 | alofi
# Processing Record 22 of Set 12 | chunskiy
# Processing Record 23 of Set 12 | ekhabi
# Processing Record 24 of Set 12 | atbasar
# Processing Record 25 of Set 12 | stalowa wola
# Processing Record 26 of Set 12 | norilsk
# Processing Record 27 of Set 12 | darfo
# Processing Record 28 of Set 12 | haines junction
# Processing Record 29 of Set 12 | kochevo
# Processing Record 30 of Set 12 | goma
# Processing Record 31 of Set 12 | doha
# Processing Record 32 of Set 12 | camacha
# Processing Record 33 of Set 12 | inirida
# Processing Record 34 of Set 12 | bonavista
# Processing Record 35 of Set 12 | igrim
# Processing Record 36 of Set 12 | wuda
# Processing Record 37 of Set 12 | tura
# Processing Record 38 of Set 12 | konya
# Processing Record 39 of Set 12 | sarakhs
# Processing Record 40 of Set 12 | loa janan
# Processing Record 41 of Set 12 | tawkar
# tawkar has not been found. Skipping...
# Processing Record 42 of Set 12 | kuytun
# Processing Record 43 of Set 12 | pangnirtung
# Processing Record 44 of Set 12 | salym
# Processing Record 45 of Set 12 | quatre cocos
# Processing Record 46 of Set 12 | oum hadjer
# Processing Record 47 of Set 12 | warqla
# warqla has not been found. Skipping...
# Processing Record 48 of Set 12 | kidal
# Processing Record 49 of Set 12 | magadan
# Processing Record 50 of Set 12 | luancheng
# Processing Record 1 of Set 13 | sulina
# Processing Record 2 of Set 13 | tumannyy
# tumannyy has not been found. Skipping...
# Processing Record 3 of Set 13 | mayor pablo lagerenza
# Processing Record 4 of Set 13 | eenhana
# Processing Record 5 of Set 13 | ocos
# Processing Record 6 of Set 13 | laguna
# Processing Record 7 of Set 13 | khryashchevka
# Processing Record 8 of Set 13 | chillan
# Processing Record 9 of Set 13 | hami
# Processing Record 10 of Set 13 | ambovombe
# Processing Record 11 of Set 13 | bassano
# Processing Record 12 of Set 13 | marawi
# Processing Record 13 of Set 13 | asheville
# Processing Record 14 of Set 13 | sorochinsk
# Processing Record 15 of Set 13 | touros
# Processing Record 16 of Set 13 | angoche
# Processing Record 17 of Set 13 | sakakah
# Processing Record 18 of Set 13 | hokitika
# Processing Record 19 of Set 13 | makaryev
# Processing Record 20 of Set 13 | amuntai
# Processing Record 21 of Set 13 | rabo de peixe
# Processing Record 22 of Set 13 | bac lieu
# Processing Record 23 of Set 13 | gadag
# Processing Record 24 of Set 13 | iralaya
# Processing Record 25 of Set 13 | alice town
# Processing Record 26 of Set 13 | shenxian
# Processing Record 27 of Set 13 | seredka
# Processing Record 28 of Set 13 | lazaro cardenas
# Processing Record 29 of Set 13 | turbat
# Processing Record 30 of Set 13 | morgan city
# Processing Record 31 of Set 13 | tricase
# Processing Record 32 of Set 13 | manicore
# Processing Record 33 of Set 13 | puerto leguizamo
# Processing Record 34 of Set 13 | desdunes
# Processing Record 35 of Set 13 | hurghada
# Processing Record 36 of Set 13 | sao joao da barra
# Processing Record 37 of Set 13 | aykhal
# Processing Record 38 of Set 13 | curup
# Processing Record 39 of Set 13 | fort saint john
# fort saint john has not been found. Skipping...
# Processing Record 40 of Set 13 | pemangkat
# Processing Record 41 of Set 13 | maputo
# Processing Record 42 of Set 13 | djambala
# Processing Record 43 of Set 13 | calama
# Processing Record 44 of Set 13 | yerbogachen
# Processing Record 45 of Set 13 | pailon
# Processing Record 46 of Set 13 | chipinge
# Processing Record 47 of Set 13 | barraute
# Processing Record 48 of Set 13 | freeport
# Processing Record 49 of Set 13 | krasnyy oktyabr
# Processing Record 50 of Set 13 | cumberland
# Processing Record 1 of Set 14 | chilca
# Processing Record 2 of Set 14 | dutse
# Processing Record 3 of Set 14 | lagoa
# Processing Record 4 of Set 14 | hays
# Processing Record 5 of Set 14 | pustoshka
# Processing Record 6 of Set 14 | safonovo
# Processing Record 7 of Set 14 | cangucu
# Processing Record 8 of Set 14 | upington
# Processing Record 9 of Set 14 | general roca
# Processing Record 10 of Set 14 | ardakan
# Processing Record 11 of Set 14 | bereznik
# Processing Record 12 of Set 14 | prince rupert
# Processing Record 13 of Set 14 | wanning
# Processing Record 14 of Set 14 | rafaela
# Processing Record 15 of Set 14 | moussoro
# Processing Record 16 of Set 14 | solton
# Processing Record 17 of Set 14 | lavumisa
# Processing Record 18 of Set 14 | dukat
# Processing Record 19 of Set 14 | erzin
# Processing Record 20 of Set 14 | muswellbrook
# Processing Record 21 of Set 14 | puerto santander
# Processing Record 22 of Set 14 | wamba
# Processing Record 23 of Set 14 | rockland
# Processing Record 24 of Set 14 | mecca
# Processing Record 25 of Set 14 | puri
# Processing Record 26 of Set 14 | vostok
# Processing Record 27 of Set 14 | buala
# Processing Record 28 of Set 14 | coburg
# Processing Record 29 of Set 14 | nguiu
# nguiu has not been found. Skipping...
# Processing Record 30 of Set 14 | hihifo
# hihifo has not been found. Skipping...
# Processing Record 31 of Set 14 | kalabo
# Processing Record 32 of Set 14 | seymchan
# Processing Record 33 of Set 14 | warri
# Processing Record 34 of Set 14 | beira
# Processing Record 35 of Set 14 | port macquarie
# Processing Record 36 of Set 14 | soyo
# Processing Record 37 of Set 14 | progreso
# Processing Record 38 of Set 14 | paka
# Processing Record 39 of Set 14 | wulanhaote
# wulanhaote has not been found. Skipping...
# Processing Record 40 of Set 14 | matara
# Processing Record 41 of Set 14 | ludvika
# Processing Record 42 of Set 14 | kavaratti
# Processing Record 43 of Set 14 | orzhytsya
# Processing Record 44 of Set 14 | batanovci
# Processing Record 45 of Set 14 | mouriai
# mouriai has not been found. Skipping...
# Processing Record 46 of Set 14 | bluefield
# Processing Record 47 of Set 14 | ust-kamchatsk
# ust-kamchatsk has not been found. Skipping...
# Processing Record 48 of Set 14 | kautokeino
# Processing Record 49 of Set 14 | schongau
# Processing Record 50 of Set 14 | ornskoldsvik
# Processing Record 1 of Set 15 | galveston
# Processing Record 2 of Set 15 | dryden
# Processing Record 3 of Set 15 | omboue
# Processing Record 4 of Set 15 | cusco
# Processing Record 5 of Set 15 | umm kaddadah
# Processing Record 6 of Set 15 | banda aceh
# Processing Record 7 of Set 15 | galle
# Processing Record 8 of Set 15 | codrington
# Processing Record 9 of Set 15 | fatezh
# Processing Record 10 of Set 15 | daru
# Processing Record 11 of Set 15 | nome
# Processing Record 12 of Set 15 | wanaka
# Processing Record 13 of Set 15 | baykit
# Processing Record 14 of Set 15 | zykovo
# Processing Record 15 of Set 15 | khandyga
# Processing Record 16 of Set 15 | mokshan
# Processing Record 17 of Set 15 | sorland
# Processing Record 18 of Set 15 | otta
# Processing Record 19 of Set 15 | gao
# Processing Record 20 of Set 15 | newport
# Processing Record 21 of Set 15 | pokhara
# Processing Record 22 of Set 15 | deputatskiy
# Processing Record 23 of Set 15 | san andres
# Processing Record 24 of Set 15 | san policarpo
# Processing Record 25 of Set 15 | murupara
# Processing Record 26 of Set 15 | sabang
# Processing Record 27 of Set 15 | urengoy
# Processing Record 28 of Set 15 | mangrol
# Processing Record 29 of Set 15 | high rock
# Processing Record 30 of Set 15 | panaba
# Processing Record 31 of Set 15 | filadelfia
# Processing Record 32 of Set 15 | suluq
# Processing Record 33 of Set 15 | esil
# Processing Record 34 of Set 15 | matagami
# Processing Record 35 of Set 15 | kieta
# Processing Record 36 of Set 15 | iracoubo
# Processing Record 37 of Set 15 | malinovoye ozero
# Processing Record 38 of Set 15 | moctezuma
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Ushuaia -54.8000  -68.3000     53.22        62          75
# 1   Tuktoyaktuk  69.4541 -133.0374    -16.60        69           0
# 2     Saskylakh  71.9167  114.0833    -22.50       100          94
# 3      Hermanus -34.4187   19.2345     60.80        85         100
# 4     Carnarvon -24.8667  113.6333     80.67        61         100
# 5       Mataura -46.1927  168.8643     42.62        92           5
# 6     Cape Town -33.9258   18.4232     64.11        80          20
# 7  Ponta Do Sol  32.6667  -17.1000     65.01        70          43
# 8      Itaituba  -4.2761  -55.9836     84.36        84          40
# 9       Cayenne   4.9333  -52.3333     82.44         1          75
#
#    Wind Speed Country Weather Description
# 0       18.41      AR       broken clouds
# 1        9.22      CA           clear sky
# 2        2.86      RU     overcast clouds
# 3       14.27      ZA          light rain
# 4        5.75      AU     overcast clouds
# 5        2.80      NZ           clear sky
# 6       18.41      ZA          few clouds
# 7        6.55      PT    scattered clouds
# 8        8.05      BR    scattered clouds
# 9       14.97      GF       broken clouds

# %%
# reorder columns to match challenge output
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Weather Description']
city_data_df = city_data_df[new_column_order]

# change weather description to current description column without doing another API call
city_data_df.rename(columns={'Weather Description': 'Current Description'}, inplace=True)

city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Ushuaia      AR -54.8000  -68.3000     53.22        62          75
# 1   Tuktoyaktuk      CA  69.4541 -133.0374    -16.60        69           0
# 2     Saskylakh      RU  71.9167  114.0833    -22.50       100          94
# 3      Hermanus      ZA -34.4187   19.2345     60.80        85         100
# 4     Carnarvon      AU -24.8667  113.6333     80.67        61         100
# 5       Mataura      NZ -46.1927  168.8643     42.62        92           5
# 6     Cape Town      ZA -33.9258   18.4232     64.11        80          20
# 7  Ponta Do Sol      PT  32.6667  -17.1000     65.01        70          43
# 8      Itaituba      BR  -4.2761  -55.9836     84.36        84          40
# 9       Cayenne      GF   4.9333  -52.3333     82.44         1          75
#
#    Wind Speed Current Description
# 0       18.41       broken clouds
# 1        9.22           clear sky
# 2        2.86     overcast clouds
# 3       14.27          light rain
# 4        5.75     overcast clouds
# 5        2.80           clear sky
# 6       18.41          few clouds
# 7        6.55    scattered clouds
# 8        8.05    scattered clouds
# 9       14.97       broken clouds

# %%
# output dataframe into csv
output_data_file = 'WeatherPy_Database.csv'

city_data_df.to_csv(output_data_file, index_label='City_ID')
